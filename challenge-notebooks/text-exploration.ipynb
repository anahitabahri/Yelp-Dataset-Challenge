# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

import statsmodels.formula.api as smf
import statsmodels.api as sm

from textblob import TextBlob
from textblob.classifiers import NaiveBayesClassifier
from textblob.sentiments import NaiveBayesAnalyzer
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
data = pd.read_csv('../../yelp-data/new_data/final_data/manip_data.csv')

# %%
sns.countplot(y='ReviewStars', color='#7C7CE0', data=data)
plt.xlabel('Count')
plt.ylabel('Stars')
plt.title('Count of Reviews by Stars')

# %%
data['waste money'] = data['text'].str.contains('waste money')
data['delicious'] = data['text'].str.contains('delicious')
data['worst'] = data['text'].str.contains('worst')
data['horrible'] = data['text'].str.contains('horrible')
data['bland'] = data['text'].str.contains('bland')
data['slow'] = data['text'].str.contains('slow')
data['overcooked'] = data['text'].str.contains('overcooked')
data['friendly'] = data['text'].str.contains('friendly')
data['manager'] = data['text'].str.contains('manager')
data['rude'] = data['text'].str.contains('rude')
data['perfection'] = data['text'].str.contains('perfection')
data['tender'] = data['text'].str.contains('tender')
data['juicy'] = data['text'].str.contains('juicy')
data['fries'] = data['text'].str.contains('fries')
data['sauce'] = data['text'].str.contains('sauce')
data['however'] = data['text'].str.contains('however')
data['hate'] = data['text'].str.contains('hate')
data['special'] = data['text'].str.contains('special')
data['rare'] = data['text'].str.contains('rare')
data['undercooked'] = data['text'].str.contains('undercooked')
data['medium'] = data['text'].str.contains('medium')
data['lovely'] = data['text'].str.contains('lovely')
data['tasty'] = data['text'].str.contains('tasty')
data['experience'] = data['text'].str.contains('experience')
data['flavorless'] = data['text'].str.contains('flavorless')
data['money'] = data['text'].str.contains('money')
data['price'] = data['text'].str.contains('price')
data['service'] = data['text'].str.contains('service')

# %%
sns.barplot(x="ReviewStars", y="delicious", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "delicious"')

# %%
sns.barplot(x="ReviewStars", y="slow", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "slow"')

# %%
sns.barplot(x="ReviewStars", y="bland", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "bland"')

# %%
sns.barplot(x="ReviewStars", y="overcooked", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "overcooked"')

# %%
sns.barplot(x="ReviewStars", y="friendly", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "friendly"')

# %%
sns.barplot(x="ReviewStars", y="rude", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "rude"')

# %%
sns.barplot(x="ReviewStars", y="manager", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "manager"')

# %%
sns.barplot(x="ReviewStars", y="perfection", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "perfection"')

# %%
sns.barplot(x="ReviewStars", y="tender", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "tender"')

# %%
sns.barplot(x="ReviewStars", y="juicy", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "juicy"')

# %%
sns.barplot(x="ReviewStars", y="fries", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "fries"')

# %%
sns.barplot(x="ReviewStars", y="sauce", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "sauce"')

# %%
sns.barplot(x="ReviewStars", y="however", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "however"')

# %%
sns.barplot(x="ReviewStars", y="hate", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "hate"')

# %%
sns.barplot(x="ReviewStars", y="special", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "special"')

# %%
sns.barplot(x="ReviewStars", y="undercooked", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "undercooked"')

# %%
sns.barplot(x="ReviewStars", y="rare", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "rare"')

# %%
sns.barplot(x="ReviewStars", y="medium", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "medium"')

# %%
sns.barplot(x="ReviewStars", y="lovely", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "lovely"')

# %%
sns.barplot(x="ReviewStars", y="tasty", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "tasty"')

# %%
sns.barplot(x="ReviewStars", y="experience", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "experience"')

# %%
sns.barplot(x="ReviewStars", y="flavorless", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "flavorless"')

# %%
sns.barplot(x="ReviewStars", y="money", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "money"')

# %%
sns.barplot(x="ReviewStars", y="price", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "price"')

# %%
sns.barplot(x="ReviewStars", y="waste money", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the words "waste money"')

# %%
sns.barplot(x="ReviewStars", y="service", color='#7C7CE0', data=data)
plt.ylabel('')
plt.xlabel('Stars')
plt.title('Percentage of reviews including the word "service"')

# %%
data.to_csv('../../yelp_data.csv',index=False)
