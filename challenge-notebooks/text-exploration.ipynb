# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

import statsmodels.formula.api as smf
import statsmodels.api as sm

from textblob import TextBlob
from textblob.classifiers import NaiveBayesClassifier
from textblob.sentiments import NaiveBayesAnalyzer
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
data = pd.read_csv('../../yelp-data/new_data/final_data/manip_data.csv')

# %%
sns.countplot(y='ReviewStars', data=data)
plt.xlabel('Count')
plt.title('Count of Reviews by Rating')

# %%
data['waste money'] = data['text'].str.contains('waste money')
data['delicious'] = data['text'].str.contains('delicious')
data['worst'] = data['text'].str.contains('worst')
data['horrible'] = data['text'].str.contains('horrible')
data['bland'] = data['text'].str.contains('bland')
data['slow'] = data['text'].str.contains('slow')
data['overcooked'] = data['text'].str.contains('overcooked')
data['friendly'] = data['text'].str.contains('friendly')
data['manager'] = data['text'].str.contains('manager')
data['rude'] = data['text'].str.contains('rude')
data['perfection'] = data['text'].str.contains('perfection')
data['tender'] = data['text'].str.contains('tender')
data['juicy'] = data['text'].str.contains('juicy')
data['fries'] = data['text'].str.contains('fries')
data['sauce'] = data['text'].str.contains('sauce')
data['however'] = data['text'].str.contains('however')
data['hate'] = data['text'].str.contains('hate')
data['special'] = data['text'].str.contains('special')
data['rare'] = data['text'].str.contains('rare')
data['undercooked'] = data['text'].str.contains('undercooked')
data['medium'] = data['text'].str.contains('medium')
data['lovely'] = data['text'].str.contains('lovely')
data['tasty'] = data['text'].str.contains('tasty')
data['experience'] = data['text'].str.contains('experience')
data['flavorless'] = data['text'].str.contains('flavorless')
data['money'] = data['text'].str.contains('money')
data['price'] = data['text'].str.contains('price')
data['service'] = data['text'].str.contains('service')

# %%
sns.barplot(x="ReviewStars", y="delicious", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Delicious')

# %%
sns.barplot(x="ReviewStars", y="slow", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Slow')

# %%
sns.barplot(x="ReviewStars", y="bland", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Bland')

# %%
sns.barplot(x="ReviewStars", y="overcooked", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Overcooked')

# %%
sns.barplot(x="ReviewStars", y="friendly", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Friendly')

# %%
sns.barplot(x="ReviewStars", y="rude", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Rude')

# %%
sns.barplot(x="ReviewStars", y="manager", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Manager')

# %%
sns.barplot(x="ReviewStars", y="perfection", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Perfection')

# %%
sns.barplot(x="ReviewStars", y="tender", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Tender')

# %%
sns.barplot(x="ReviewStars", y="juicy", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Juicy')

# %%
sns.barplot(x="ReviewStars", y="fries", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Fries')

# %%
sns.barplot(x="ReviewStars", y="sauce", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Sauce')

# %%
sns.barplot(x="ReviewStars", y="however", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term However')

# %%
sns.barplot(x="ReviewStars", y="hate", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Hate')

# %%
sns.barplot(x="ReviewStars", y="special", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Special')

# %%
sns.barplot(x="ReviewStars", y="undercooked", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Undercooked')

# %%
sns.barplot(x="ReviewStars", y="rare", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Rare')

# %%
sns.barplot(x="ReviewStars", y="medium", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Medium')

# %%
sns.barplot(x="ReviewStars", y="lovely", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Lovely')

# %%
sns.barplot(x="ReviewStars", y="tasty", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Tasty')

# %%
sns.barplot(x="ReviewStars", y="experience", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Experience')

# %%
sns.barplot(x="ReviewStars", y="flavorless", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Flavorless')

# %%
sns.barplot(x="ReviewStars", y="money", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Money')

# %%
sns.barplot(x="ReviewStars", y="price", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Term Price')

# %%
sns.barplot(x="ReviewStars", y="waste money", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Terms Waste Money')

# %%
sns.barplot(x="ReviewStars", y="service", data=data)
plt.xlabel('Rating')
plt.title('Percent of Reviews with the Terms Service')

# %%
data.to_csv('../../yelp_data.csv',index=False)
